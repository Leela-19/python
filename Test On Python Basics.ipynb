# %%
# 1 Print the input text without vowels using List comprehensions


a='hai'
b=['a','e','i','o','u','A','E','I','O','U']
print([i for i in a if i not in b ])
# Out:
# ['h']

# %%
# 2 Print only vowels from the text using List comprehensions


a='data'
b=['a','e','i','o','u','A','E','I','O','U']
print([i for i in a if i  in b ])
# Out:
# ['a', 'a']

# %%
# 3 print each value from the list with its index


a=[10,11,50,34]
c=[]
for i in a:
  b=str(i)+str(a.index(i))
  c.append(int(b))
print(c)
# Out:
# [100, 111, 502, 343]

# %%
# 4 This is a Python Program to print all integers that aren’t divisible by either 2 or 3 and lies between 1 and 50.


a=[]
for i in range(1,51):
  if i%2!=0 and i%3!=0:
    a.append(i)
print(a)
# Out:
# [1, 5, 7, 11, 13, 17, 19, 23, 25, 29, 31, 35, 37, 41, 43, 47, 49]

# %%
# 5 The program takes in an integer and prints the smallest divisor of the integer.


a=int(input())
b=[]
for i in range(2,11):
  if a%i==0:
    b.append(i)
print(f'divisors of {a} are : {b} ')
print(f'smallest divisor of {a} is : {min(b)}')
# Out:
# 6
# divisors of 6 are : [2, 3, 6]
# smallest divisor of 6 is : 2

# %%
#  6 Write a Python program to check if it is a strong number or not


import math
a='145'
print(f'given number is {int(a)}')
b=[]
d=0
for i in a:
  c=math.factorial(int(i))
  b.append(c)
print(f'factorials of each digit are : {b}')

for j in b:
  d=d+j
print(f'sum of factorials is : {d}')
if int(a)==d:
  print(f'{a} is a strong number')
else:
  print(f'{a} is not a strong number')
# Out:
# given number is 145
# factorials of each digit are : [1, 24, 120]
# sum of factorials is : 145
# 145 is a strong number

# %%
# 7 Write a Python program that takes input from the user and displays that input back in upper and lower cases.

a='leela usha sri'
print(f' upper case : {a.upper()}')
print(f' lower case : {a.lower()}')
# Out:
#  upper case : LEELA USHA SRI
#  lower case : leela usha sri

# %%
# 8 Write a Python program to remove spaces from a given string

a='leela usha sri'
b=''
for i in a:
  if i!=' ':
    b=b+i
print(b)
# Out:
# leelaushasri

# %%
# 9 Write a Python program to capitalize first and last letters of each word of a given string.

a='hello world'
b=a.split()
c=b[0]
d=b[1]
#print(f'first word : {c}')
#print(f'second word : {d}')
print((c[0].upper()+c[1:-1]+c[-1].upper())+' '+(d[0].upper()+d[1:-1]+d[-1].upper()))
# Out:
# HellO WorlD

# %%
# 10 write a python program to find length of a string but should not use len keyword


a='leela usha sri'
c=0
for i in a:
  c=c+1
print(f'length of the given string is : {c}')
# Out:
# length of the given string is : 14
